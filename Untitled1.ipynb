# %%
# !pip install tensorflow-model-optimization
# Out:
# Collecting tensorflow-model-optimization
#   Downloading tensorflow_model_optimization-0.8.0-py2.py3-none-any.whl.metadata (904 bytes)
# Requirement already satisfied: absl-py~=1.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow-model-optimization) (1.4.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow-model-optimization) (0.1.9)
# Collecting numpy~=1.23 (from tensorflow-model-optimization)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: six~=1.14 in /usr/local/lib/python3.11/dist-packages (from tensorflow-model-optimization) (1.17.0)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.11/dist-packages (from dm-tree~=0.1.1->tensorflow-model-optimization) (25.3.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.11/dist-packages (from dm-tree~=0.1.1->tensorflow-model-optimization) (1.17.2)
# Downloading tensorflow_model_optimization-0.8.0-py2.py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 6.4 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 66.4 MB/s eta 0:00:00
# Installing collected packages: numpy, tensorflow-model-optimization
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4 tensorflow-model-optimization-0.8.0

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image

import tensorflow as tf
import numpy as np

import tensorflow_model_optimization as tfmot
from tensorflow_model_optimization.python.core.keras.compat import keras

import os
import glob
import cv2
from sklearn.model_selection import train_test_split

print(tf.__version__)
print(np.__version__)
# Out:
# 2.18.0
# 1.26.4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
https://drive.google.com/drive/folders/1VIzYHCqp-S_NfqVjO0TtfxBFZUPotHa2?usp=sharing
https://drive.google.com/file/d/1vbj8xow94noy_DB0o5g5deraEmp8d179/view?usp=sharing


import scipy.io
mat_file = scipy.io.loadmat('/content/drive/MyDrive/imagelabels.mat')

if 'labels' in mat_file:
  labels_array = mat_file['labels']
  print(f"Shape of the labels array: {labels_array.shape}")
else:
  print("Variable 'labels' not found in the .mat file. Please check the variable name.")
# Out:
# Shape of the labels array: (1, 8189)

# %%
# %%time
first = True
IMG_SIZE = 64



files_path = '/content/drive/MyDrive/102flowers/jpg'

def get_image_number(filename):
  """Extracts the image number from a filename like 'image_00001.jpg'."""
  parts = filename.split('_')
  if len(parts) > 1:
    try:
      # Extract the part after '_' and before '.jpg', then convert to int
      number_str = parts[-1].split('.')[0]
      return int(number_str)
    except ValueError:
      return float('inf') # Put non-standard filenames at the end
  return float('inf') # Put filenames without '_' at the end


items = sorted(glob.glob(files_path + '/*.*'), key=get_image_number)
print(items)
tmpx = np.array([(cv2.resize(cv2.cvtColor(cv2.imread(x, cv2.IMREAD_COLOR), cv2.COLOR_BGR2RGB), (IMG_SIZE,IMG_SIZE))) for x in items])
tmpy = np.array(labels_array)
tmpy = tmpy.reshape(-1, 1)

print(tmpx.shape)
print(tmpy.shape)
# Out:
# ['/content/drive/MyDrive/102flowers/jpg/image_00001.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00002.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00003.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00004.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00005.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00006.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00007.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00008.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00009.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00010.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00011.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00012.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00013.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00014.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00015.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00016.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00017.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00018.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00019.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00020.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00021.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00022.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00023.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00024.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00025.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00026.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00027.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00028.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00029.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00030.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00031.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00032.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00033.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00034.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00035.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00036.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00037.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00038.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00039.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00040.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00041.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00042.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00043.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00044.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00045.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00046.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00047.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00048.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00049.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00050.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00051.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00052.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00053.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00054.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00055.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00056.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00057.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00058.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00059.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00060.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00061.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00062.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00063.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00064.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00065.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00066.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00067.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00068.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00069.jpg', '/content/drive/MyDrive/102flowers/jpg/image_00070.jpg', '/content ...
# (8189, 64, 64, 3)
# (8189, 1)
# CPU times: user 27.6 s, sys: 4.97 s, total: 32.6 s
# Wall time: 2min 4s

# %%
counts = np.bincount(tmpy.flatten())
print(sorted(counts))
selected_indices = np.where((counts >= 96) & (counts < 114))[0]

filtered_indices = np.isin(tmpy.flatten(), selected_indices)
tmpx_filtered = tmpx[filtered_indices]
tmpy_filtered = tmpy[filtered_indices]

print(f"Shape of filtered tmpx: {tmpx_filtered.shape}")
print(f"Shape of filtered tmpy: {tmpy_filtered.shape}")

print(np.unique(tmpy_filtered).tolist())

cls_map = {}
for i, idx in enumerate(np.unique(tmpy_filtered).tolist()):
  cls_map[idx] = i

print(cls_map)

tmpy_filtered = np.array([cls_map[label] for label in tmpy_filtered.flatten()]).reshape(-1, 1)
print(np.unique(tmpy_filtered))

print("\nShape after remapping:")
print(tmpx_filtered.shape)
print(tmpy_filtered.shape)
# Out:
# [0, 40, 40, 40, 40, 40, 40, 40, 41, 41, 41, 41, 41, 42, 42, 43, 45, 45, 45, 46, 46, 46, 48, 48, 49, 49, 49, 49, 49, 50, 52, 52, 54, 54, 54, 55, 56, 56, 56, 58, 58, 59, 59, 60, 61, 61, 62, 63, 63, 63, 65, 66, 66, 66, 67, 67, 67, 67, 71, 71, 75, 76, 78, 78, 82, 82, 82, 85, 85, 85, 85, 86, 87, 87, 91, 91, 92, 93, 93, 96, 102, 105, 107, 108, 109, 109, 112, 114, 120, 127, 128, 130, 131, 137, 154, 162, 166, 171, 184, 194, 196, 251, 258]
# Shape of filtered tmpx: (848, 64, 64, 3)
# Shape of filtered tmpy: (848, 1)
# [37, 56, 60, 65, 72, 76, 80, 82]
# {37: 0, 56: 1, 60: 2, 65: 3, 72: 4, 76: 5, 80: 6, 82: 7}
# [0 1 2 3 4 5 6 7]
#
# Shape after remapping:
# (848, 64, 64, 3)
# (848, 1)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(tmpx_filtered, tmpy_filtered, test_size=0.1, random_state=123)
print(xtrain.shape)
print(xtest.shape)
print(ytrain.shape)
print(ytest.shape)

train_data = xtrain.copy()
train_labels = ytrain.copy()
test_data = xtest.copy()
test_labels = ytest.copy()
# Out:
# (763, 64, 64, 3)
# (85, 64, 64, 3)
# (763, 1)
# (85, 1)

# %%
train_data = train_data / 255.0
test_data = test_data / 255.0

print(train_data.shape)
print(train_labels.shape)
print(test_data.shape)
print(test_labels.shape)
print(test_labels[0])
print(train_data[0])
# Out:
# (763, 64, 64, 3)
# (763, 1)
# (85, 64, 64, 3)
# (85, 1)
# [1]
# [[[0.89019608 0.98431373 0.83529412]
#   [0.98039216 0.99215686 0.86666667]
#   [0.28627451 0.36862745 0.17647059]
#   ...
#   [0.13333333 0.27058824 0.0745098 ]
#   [0.17254902 0.32156863 0.10980392]
#   [0.24313725 0.3372549  0.15294118]]
#
#  [[0.72941176 0.88627451 0.63529412]
#   [0.63137255 0.71372549 0.43137255]
#   [0.0745098  0.17647059 0.01568627]
#   ...
#   [0.09411765 0.18431373 0.07058824]
#   [0.09019608 0.19215686 0.04705882]
#   [0.41176471 0.53333333 0.41176471]]
#
#  [[0.65098039 0.81176471 0.53333333]
#   [0.15686275 0.36078431 0.00784314]
#   [0.23137255 0.32156863 0.09411765]
#   ...
#   [0.1372549  0.19607843 0.09019608]
#   [0.11372549 0.22745098 0.05490196]
#   [0.19215686 0.29019608 0.17647059]]
#
#  ...
#
#  [[0.76078431 0.92156863 0.70196078]
#   [0.8627451  0.98039216 0.75686275]
#   [0.51764706 0.65490196 0.30196078]
#   ...
#   [0.16862745 0.32156863 0.10588235]
#   [0.17647059 0.37254902 0.09803922]
#   [0.6745098  0.88627451 0.55686275]]
#
#  [[0.76078431 0.90196078 0.58823529]
#   [0.5254902  0.76078431 0.34117647]
#   [0.54509804 0.71764706 0.25098039]
#   ...
#   [0.14509804 0.30196078 0.09019608]
#   [0.19607843 0.35686275 0.12156863]
#   [0.88235294 0.98823529 0.78823529]]
#
#  [[0.98431373 1.         0.83137255]
#   [0.47843137 0.74509804 0.27843137]
#   [0.55686275 0.83529412 0.12156863]
#   ...
#   [0.18431373 0.34117647 0.12941176]
#   [0.14901961 0.30196078 0.07843137]
#   [0.83137255 1.         0.7254902 ]]]

# %%
# 3. Keras Model 정의, Model summary -> 3 Conv Layer + ReLU + Dropout으로 구성할 것 (출력 예 참조)
model = tf.keras.models.Sequential()
#input layer
model.add(tf.keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3)))
# conv 1
model.add(tf.keras.layers.Conv2D(64, 3, padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))
# conv 2
model.add(tf.keras.layers.Conv2D(64, 3, padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))
# conv 3
model.add(tf.keras.layers.Conv2D(96, 3, padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))
# dense layers
model.add(tf.keras.layers.Conv2D(128, 3, padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Activation('relu'))

model.add(tf.keras.layers.Conv2D(128, 3, padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Activation('relu'))

model.add(tf.keras.layers.Flatten(name='flatten'))
model.add(tf.keras.layers.Dense(23, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_80 (Conv2D)          (None, 64, 64, 64)        1792
#
#  batch_normalization_80 (Ba  (None, 64, 64, 64)        256
#  tchNormalization)
#
#  activation_80 (Activation)  (None, 64, 64, 64)        0
#
#  max_pooling2d_48 (MaxPooli  (None, 32, 32, 64)        0
#  ng2D)
#
#  conv2d_81 (Conv2D)          (None, 32, 32, 64)        36928
#
#  batch_normalization_81 (Ba  (None, 32, 32, 64)        256
#  tchNormalization)
#
#  activation_81 (Activation)  (None, 32, 32, 64)        0
#
#  max_pooling2d_49 (MaxPooli  (None, 16, 16, 64)        0
#  ng2D)
#
#  conv2d_82 (Conv2D)          (None, 16, 16, 96)        55392
#
#  batch_normalization_82 (Ba  (None, 16, 16, 96)        384
#  tchNormalization)
#
#  activation_82 (Activation)  (None, 16, 16, 96)        0
#
#  max_pooling2d_50 (MaxPooli  (None, 8, 8, 96)          0
#  ng2D)
#
#  conv2d_83 (Conv2D)          (None, 8, 8, 128)         110720
#
#  batch_normalization_83 (Ba  (None, 8, 8, 128)         512
#  tchNormalization)
#
#  activation_83 (Activation)  (None, 8, 8, 128)         0
#
#  conv2d_84 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_84 (Ba  (None, 8, 8, 128)         512
#  tchNormalization)
#
#  activation_84 (Activation)  (None, 8, 8, 128)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense_18 (Dense)            (None, 23)                188439
#
# =================================================================
# Total params: 542775 (2.07 MB)
# Trainable params: 541815 (2.07 MB)
# Non-trainable params: 960 (3.75 KB)
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# prompt: label 22개까지 5개씩 그리기 (총 110개)

def plot_images_by_label(data, labels, num_images_per_label=5, num_labels_to_plot=22):
    """
    Displays a few images for each of the first `num_labels_to_plot` labels.

    Args:
        data (np.ndarray): The image data.
        labels (np.ndarray): The corresponding labels for the images.
        num_images_per_label (int): The number of images to display per label.
        num_labels_to_plot (int): The maximum number of unique labels to plot.
    """
    unique_labels = np.unique(labels)
    labels_to_plot = unique_labels[:num_labels_to_plot]

    # Calculate grid size
    n_cols = num_images_per_label
    n_rows = min(len(labels_to_plot), num_labels_to_plot)

    fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 3, n_rows * 3))
    fig.suptitle("Sample Images per Label")

    axes = axes.flatten() # Flatten axes array for easy iteration

    img_count = 0
    for i, label in enumerate(labels_to_plot):
        if i >= num_labels_to_plot:
            break # Stop if we have plotted enough labels

        label_indices = np.where(labels == label)[0]
        selected_indices = label_indices[:num_images_per_label]

        for j, idx in enumerate(selected_indices):
            ax = axes[img_count]
            ax.imshow(data[idx])
            ax.set_title(f"Label: {label}")
            ax.axis('off')
            img_count += 1

    # Hide any unused subplots
    for i in range(img_count, len(axes)):
        fig.delaxes(axes[i])

    plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # Adjust layout to make space for suptitle
    plt.show()



# Example usage:
plot_images_by_label(test_data, test_labels.flatten(), num_images_per_label=5, num_labels_to_plot=8)

# %%
y_out = model.predict(test_data)
y_max = np.argmax(y_out, axis=1).reshape((-1, 1))
Make_Result_Plot("Before Training", test_data, test_labels, y_max)
# Out:
# 11/11 [==============================] - 0s 4ms/step

# %%
# %%time
history = model.fit(train_data, train_labels, epochs=50, batch_size=8,
                 validation_data=(test_data, test_labels) )
# Out:
# Epoch 1/50
# 96/96 [==============================] - 5s 15ms/step - loss: 1.8723 - accuracy: 0.5111 - val_loss: 4.4106 - val_accuracy: 0.1294
# Epoch 2/50
# 96/96 [==============================] - 1s 9ms/step - loss: 1.4614 - accuracy: 0.6121 - val_loss: 2.7643 - val_accuracy: 0.1412
# Epoch 3/50
# 96/96 [==============================] - 1s 7ms/step - loss: 0.8008 - accuracy: 0.7339 - val_loss: 6.0016 - val_accuracy: 0.1529
# Epoch 4/50
# 96/96 [==============================] - 1s 7ms/step - loss: 0.8619 - accuracy: 0.7510 - val_loss: 3.4465 - val_accuracy: 0.4118
# Epoch 5/50
# 96/96 [==============================] - 1s 6ms/step - loss: 0.4676 - accuracy: 0.8598 - val_loss: 1.5795 - val_accuracy: 0.6000
# Epoch 6/50
# 96/96 [==============================] - 1s 6ms/step - loss: 0.3378 - accuracy: 0.8873 - val_loss: 0.8115 - val_accuracy: 0.8000
# Epoch 7/50
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2961 - accuracy: 0.9122 - val_loss: 0.6294 - val_accuracy: 0.8235
# Epoch 8/50
# 96/96 [==============================] - 1s 6ms/step - loss: 0.2556 - accuracy: 0.9279 - val_loss: 0.8107 - val_accuracy: 0.7647
# Epoch 9/50
# 96/96 [==============================] - 1s 8ms/step - loss: 0.1216 - accuracy: 0.9528 - val_loss: 0.9498 - val_accuracy: 0.7882
# Epoch 10/50
# 96/96 [==============================] - 1s 6ms/step - loss: 0.0913 - accuracy: 0.9699 - val_loss: 1.3235 - val_accuracy: 0.7647
# Epoch 11/50
# 96/96 [==============================] - 1s 7ms/step - loss: 0.0329 - accuracy: 0.9934 - val_loss: 0.5081 - val_accuracy: 0.8706
# Epoch 12/50
# 96/96 [==============================] - 1s 6ms/step - loss: 0.0149 - accuracy: 0.9961 - val_loss: 0.4756 - val_accuracy: 0.8588
# Epoch 13/50
# 96/96 [==============================] - 1s 7ms/step - loss: 0.0407 - accuracy: 0.9803 - val_loss: 3.9329 - val_accuracy: 0.4941
# Epoch 14/50
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1399 - accuracy: 0.9554 - val_loss: 2.9177 - val_accuracy: 0.6235
# Epoch 15/50
# 96/96 [==============================] - 1s 6ms/step - loss: 0.4462 - accuracy: 0.8702 - val_loss: 3.1539 - val_accuracy: 0.6706
# Epoch 16/50
# 96/96 [==============================] - 1s 7ms/step - loss: 0.2142 - accuracy: 0.9345 - val_loss: 1.2227 - val_accuracy: 0.7412
# Epoch 17/50
# 96/96 [==============================] - 1s 7ms/step - loss: 0.3684 - accuracy: 0.9214 - val_loss: 1.3784 - val_accuracy: 0.7647
# Epoch 18/50
# 96/96 [==============================] - 1s 6ms/step - loss: 0.3266 - accuracy: 0.9096 - val_loss: 1.3141 - val_accuracy: 0.7765
# Epoch 19/50
# 96/96 [==============================] - 1s 8ms/step - loss: 0.1300 - accuracy: 0.9528 - val_loss: 0.8189 - val_accuracy: 0.8000
# Epoch 20/50
# 96/96 [==============================] - 1s 9ms/step - loss: 0.0561 - accuracy: 0.9803 - val_loss: 0.8095 - val_accuracy: 0.8118
# Epoch 21/50
# 96/96 [==============================] - 1s 8ms/step - loss: 0.0148 - accuracy: 0.9961 - val_loss: 0.5124 - val_accuracy: 0.8588
# Epoch 22/50
# 96/96 [==============================] - 1s 10ms/step - loss: 0.0050 - accuracy: 0.9974 - val_loss: 0.5373 - val_accuracy: 0.8588
# Epoch 23/50
# 96/96 [==============================] - 1s 8ms/step - loss: 0.0121 - accuracy: 0.9987 - val_loss: 0.5755 - val_accuracy: 0.8235
# Epoch 24/50
# 96/96 [==============================] - 1s 6ms/step - loss: 0.0199 - accuracy: 0.9974 - val_loss: 0.8960 - val_accuracy: 0.8118
# Epoch 25/50
# 96/96 [==============================] - 1s 7ms/step - loss: 0.0126 - accuracy: 0.9961 - val_loss: 0.6689 - val_accuracy: 0.8235
# Epoch 26/50
# 96/96 [==============================] - 1s 6ms/step - loss: 0.0367 - accuracy: 0.9856 - val_loss: 2.2293 - val_accuracy: 0.6118
# Epoch 27/50
# 96/96 [==============================] - 1s 7ms/step - loss: 0.0917 - accuracy: 0.9699 - val_loss: 1.5105 - val_accuracy: 0.7294
# Epoch 28/50
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1230 - accuracy: 0.9699 - val_loss: 1.3150 - val_accuracy: 0.8353
# Epoch 29/50
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1600 - accuracy: 0.9581 - val_loss: 1.0072 - val_accuracy: 0.8353
# Epoch 30/50
# 96/96 [==============================] - 1s 7ms/step - loss: 0.1090 - accuracy: 0.9712 - val_loss: 0.9751 - val_accuracy: 0.8471
# Epoch 31/50
# 96/96 [==============================] - 1s 6ms/step - loss: 0.0472 - accuracy: 0.9843 - val_loss: 1.1278 - val_accuracy: 0.8000
# Epoch 32/50
# 96/96 [==============================] - 1s 7ms/step - loss: 0.0307 - accuracy: 0.9921 - val_loss: 1.1697 - val_accuracy: 0.8118
# Epoch 33/50
# 96/96 [==============================] - 1s 7ms/step - loss: 0.0426 - accuracy: 0.9869 - val_loss: 0.9135 - val_accuracy: 0.8353
# Epoch 34/50
# 96/96 [==============================] - 1s 6ms/step - loss: 0.0224 - accuracy: 0.9908 - val_loss: 0.5903 - val_accuracy: 0.8941
# Epoch 35/50
# 96/96 [==============================] - 1s 7ms/step - loss: 0.0732 - accuracy: 0.9817 - val_loss: 2.1975 - val_accuracy: 0.7059
# Epoch 36/50
# 96/96 [==============================] - 1s 6ms/step - loss: 0.1156 - accuracy: 0.9659 - val_loss: 1.0385 - val_accuracy: 0.7765
# Epoch 37/50
# 96/96 [==============================] - 1s 6ms/step - loss: 0.0826 - accuracy: 0.9803 - val_loss: 1.3518 - val_accuracy: 0.8000
# Epoch 38/50
# 96/96 [==============================] - 1s 7ms/step - loss: 0.0166 - accuracy: 0.9934 - val_loss: 0.9823 - val_accuracy: 0.8588
# Epoch 39/50
# 96/96 [==============================] - 1s 9ms/step - loss: 0.0066 - accuracy: 0.9974 - val_loss: 1.3530 - val_accuracy: 0.8118
# Epoch 40/50
# 96/96 [==============================] - 1s 8ms/step - loss: 0.0023 - accuracy: 0.9987 - val_loss: 1.0297 - val_accuracy: 0.8706
# Epoch 41/50
# 96/96 [==============================] - 1s 10ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.9247 - val_accuracy: 0.8588
# Epoch 42/50
# 96/96 [==============================] - 1s 9ms/step - loss: 3.7748e-04 - accuracy: 1.0000 - val_loss: 0.9346 - val_accuracy: 0.8588
# Epoch 43/50
# 96/96 [==============================] - 1s 7ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.9629 - val_accuracy: 0.8588
# Epoch 44/50
# 96/96 [==============================] - 1s 7ms/step - loss: 7.9089e-04 - accuracy: 1.0000 - val_loss: 0.9452 - val_accuracy: 0.8471
# Epoch 45/50
# 96/96 [==============================] - 1s 6ms/step - loss: 4.0976e-04 - accuracy: 1.0000 - val_loss: 0.8328 - val_accuracy: 0.8588
# Epoch 46/50
# 96/96 [==============================] - 1s 7ms/step - loss: 1.9423e-04 - accuracy: 1.0000 - val_loss: 0.8030 - val_accuracy: 0.8471
# Epoch 47/50
# 96/96 [==============================] - 1s 7ms/step - loss: 0.0198 - accuracy: 0.9974 - val_loss: 1.1238 - val_accuracy: 0.8235
# Epoch 48/50
# 96/96 [==============================] - 1s 7ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.9532 - val_accuracy: 0.8353
# Epoch 49/50
# 96/96 [==============================] - 1s 6ms/step - loss: 4.7399e-04 - accuracy: 1.0000 - val_loss: 0.9495 - val_accuracy: 0.8353
# Epoch 50/50
# 96/96 [==============================] - 1s 6ms/step - loss: 4.7763e-04 - accuracy: 1.0000 - val_loss: 0.9166 - val_accuracy: 0.8353
# CPU times: user 38.4 s, sys: 1.76 s, total: 40.2 s
# Wall time: 37.7 s

# %%
plt.figure(figsize=(6, 10))
plt.subplot(2, 1, 1)
plt.title('Accuracy')
plt.plot(history.history['accuracy'], 'b', label='train_accuracy')
plt.plot(history.history['val_accuracy'], 'g', label='val_accuracy')
plt.ylim([0.7,1])
plt.grid(True)
plt.ylabel('Accuracy')
plt.legend(loc='best')

plt.subplot(2, 1, 2)
plt.title('Loss')
plt.plot(history.history['loss'], 'b', label='train_loss')
plt.plot(history.history['val_loss'], 'g', label='val_loss')
plt.ylim([0,0.5])
plt.grid(True)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='best')
plt.show()

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_baseline_model = converter.convert()
litert_model_path = "/content"
import pathlib

tflite_models_dir = pathlib.Path(litert_model_path)
tflite_models_dir.mkdir(exist_ok=True, parents=True)

tflite_baseline_model_file = tflite_models_dir/"fm_qat_model_bl.tflite"
size_baseline_model = tflite_baseline_model_file.write_bytes(tflite_baseline_model)
interpreter_base = tf.lite.Interpreter(model_content=tflite_baseline_model)
interpreter_base.allocate_tensors()
q_aware_model = tfmot.quantization.keras.quantize_model(model)

q_aware_model.compile(optimizer='adam',
                      loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                      metrics=['accuracy'])

q_aware_model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  quantize_layer_2 (Quantize  (None, 64, 64, 3)         3
#  Layer)
#
#  quant_conv2d_80 (QuantizeW  (None, 64, 64, 64)        1921
#  rapperV2)
#
#  quant_batch_normalization_  (None, 64, 64, 64)        257
#  80 (QuantizeWrapperV2)
#
#  quant_activation_80 (Quant  (None, 64, 64, 64)        3
#  izeWrapperV2)
#
#  quant_max_pooling2d_48 (Qu  (None, 32, 32, 64)        1
#  antizeWrapperV2)
#
#  quant_conv2d_81 (QuantizeW  (None, 32, 32, 64)        37057
#  rapperV2)
#
#  quant_batch_normalization_  (None, 32, 32, 64)        257
#  81 (QuantizeWrapperV2)
#
#  quant_activation_81 (Quant  (None, 32, 32, 64)        3
#  izeWrapperV2)
#
#  quant_max_pooling2d_49 (Qu  (None, 16, 16, 64)        1
#  antizeWrapperV2)
#
#  quant_conv2d_82 (QuantizeW  (None, 16, 16, 96)        55585
#  rapperV2)
#
#  quant_batch_normalization_  (None, 16, 16, 96)        385
#  82 (QuantizeWrapperV2)
#
#  quant_activation_82 (Quant  (None, 16, 16, 96)        3
#  izeWrapperV2)
#
#  quant_max_pooling2d_50 (Qu  (None, 8, 8, 96)          1
#  antizeWrapperV2)
#
#  quant_conv2d_83 (QuantizeW  (None, 8, 8, 128)         110977
#  rapperV2)
#
#  quant_batch_normalization_  (None, 8, 8, 128)         513
#  83 (QuantizeWrapperV2)
#
#  quant_activation_83 (Quant  (None, 8, 8, 128)         3
#  izeWrapperV2)
#
#  quant_conv2d_84 (QuantizeW  (None, 8, 8, 128)         147841
#  rapperV2)
#
#  quant_batch_normalization_  (None, 8, 8, 128)         513
#  84 (QuantizeWrapperV2)
#
#  quant_activation_84 (Quant  (None, 8, 8, 128)         3
#  izeWrapperV2)
#
#  quant_flatten (QuantizeWra  (None, 8192)              1
#  pperV2)
#
#  quant_dense_18 (QuantizeWr  (None, 23)                188444
#  apperV2)
#
# =================================================================
# Total params: 543772 (2.07 MB)
# Trainable params: 541815 (2.07 MB)
# Non-trainable params: 1957 (7.64 KB)
# _________________________________________________________________

# %%
q_aware_model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# %%time
history = q_aware_model.fit(train_data, train_labels, epochs=5, batch_size=8,
                 validation_data=(test_data, test_labels) )
# Out:
# Epoch 1/5
# 96/96 [==============================] - 2s 20ms/step - loss: 0.1793 - accuracy: 0.9607 - val_loss: 1.4577 - val_accuracy: 0.7765
# Epoch 2/5
# 96/96 [==============================] - 2s 23ms/step - loss: 0.0922 - accuracy: 0.9751 - val_loss: 1.7201 - val_accuracy: 0.7412
# Epoch 3/5
# 96/96 [==============================] - 2s 20ms/step - loss: 0.0310 - accuracy: 0.9882 - val_loss: 1.3933 - val_accuracy: 0.8471
# Epoch 4/5
# 96/96 [==============================] - 2s 19ms/step - loss: 0.0431 - accuracy: 0.9856 - val_loss: 2.5525 - val_accuracy: 0.7294
# Epoch 5/5
# 96/96 [==============================] - 2s 19ms/step - loss: 0.0319 - accuracy: 0.9856 - val_loss: 1.3272 - val_accuracy: 0.8235
# CPU times: user 10.1 s, sys: 757 ms, total: 10.9 s
# Wall time: 10.4 s

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(q_aware_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

tflite_qat_model = converter.convert()

tflite_qat_model_file = tflite_models_dir/"fm_qat_model.tflite"
size_qat_model = tflite_qat_model_file.write_bytes(tflite_qat_model)
# Out:
# /usr/local/lib/python3.11/dist-packages/tensorflow/lite/python/convert.py:997: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(

# %%
# !xxd -i /content/fm_qat_model.tflite > /content/fm_qat_model.cpp
